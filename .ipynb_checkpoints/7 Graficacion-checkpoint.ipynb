# %%
year <- c('2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018')
disney <- c(11, 13, 11, 8, 12, 11, 12, 8, 10)
plot(year,disney)
# Out:
# plot without title

# %% [markdown]
# R graph galery tiene tipos de grafica y proporciona ayuda en el código
# https://www.r-graph-gallery.com/

# %%
#GGPLOT
#Se ve por capas
install.packages('ggplot2')
library(ggplot2)
# Out:
# also installing the dependency 'isoband'
#   There are binary versions available but the source versions are later:
#         binary source needs_compilation
# isoband  0.2.4  0.2.5              TRUE
# ggplot2  3.3.3  3.3.5             FALSE
#
#   Binaries will be installed
# package 'isoband' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\itzam\AppData\Local\Temp\RtmpCoWzCY\downloaded_packages
# installing the source package 'ggplot2'

# %%
peliculas <- data.frame(year,disney)

# %%
ggplot(data = peliculas,mapping = aes(x = year,
                                     y = disney)) +
      geom_point() +labs(title='disney')
#mapping es qué dato va en donde
#la capa geom cambia segun el tipo de grafica
# Out:
# plot without title

# %%
#plotly para interactivos,leaflet para mapas
